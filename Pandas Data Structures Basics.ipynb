# %%
import pandas as pd

# %%
v = pd.Series(['vinu',29])

# %%
v
# Out:
# 0    vinu
# 1      29
# dtype: object

# %%
v = pd.Series(data=['vinu',5], index=['Name','Age'])

# %%
v
# Out:
# Name    vinu
# Age        5
# dtype: object

# %%
t=pd.DataFrame(
{
    "Name": ['Vinay','Preetam','Tanvi'],
    "Age":['29','31','26'],
    "Status":['Single','Married','Married'],    
}
)
t
# Out:
#       Name Age   Status
# 0    Vinay  29   Single
# 1  Preetam  31  Married
# 2    Tanvi  26  Married

# %%
f=pd.DataFrame(
data={
        "Age":["29","31","26"],
        "Status":["Single","Married","Married"],    
    },
index=["Vinay","Preetam","Tanvi"],
columns=["Age","Status"],
)
f
# Out:
#         Age   Status
# Vinay    29   Single
# Preetam  31  Married
# Tanvi    26  Married

# %%
d=pd.read_csv('C:/Users/Administrator/Downloads/IPL IMB381IPL2013.csv')

# %%
d
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0             0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1           657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2          1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3           241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4            79     45.93  ...  120.71      28       0     0    0.00   0.00
# ..          ...       ...  ...     ...     ...     ...   ...     ...    ...
# 125           0      0.00  ...  125.64       2       0     0    0.00   0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00   0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74   7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43   7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50   9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0    13.93          2009       50000       50000
# 1     0.00          2008       50000       50000
# 2    24.90          2008      200000      350000
# 3    22.14          2011      100000      850000
# 4     0.00          2011      100000      800000
# ..     ...           ...         ...         ...
# 125   0.00          2010       50000      750000
# 126   0.00          2008      225000      225000
# 127  21.13          2011      400000     1800000
# 128  21.26          2008      200000      450000
# 129  33.00          2008      100000      110000
#
# [130 rows x 26 columns]

# %%
d.loc[127]
# Out:
# Sl.NO.                    128
# PLAYER NAME      Yuvraj Singh
# AGE                         2
# COUNTRY                   IND
# TEAM                    KXIP+
# PLAYING ROLE          Batsman
# T-RUNS                   1775
# T-WKTS                      9
# ODI-RUNS-S               8051
# ODI-SR-B                87.58
# ODI-WKTS                  109
# ODI-SR-BL                44.3
# CAPTAINCY EXP               1
# RUNS-S                   1237
# HS                         66
# AVE                     26.32
# SR-B                   131.88
# SIXERS                     67
# RUNS-C                    569
# WKTS                       23
# AVE-BL                  24.74
# ECON                     7.02
# SR-BL                   21.13
# AUCTION YEAR             2011
# BASE PRICE             400000
# SOLD PRICE            1800000
# Name: 127, dtype: object

# %%
d['SIXERS'].describe()
# Out:
# count    130.000000
# mean      17.692308
# std       23.828146
# min        0.000000
# 25%        1.000000
# 50%        6.000000
# 75%       29.750000
# max      129.000000
# Name: SIXERS, dtype: float64

# %%
d['SIXERS'].max()
# Out:
# 129

# %%
d['SIXERS'].min()
# Out:
# 0

# %%
d['SIXERS'].std()
# Out:
# 23.82814639296868

# %%
d['SIXERS'].hist()
# Out:
# <AxesSubplot:>

# %%
g=d['SOLD PRICE']
g
# Out:
# 0        50000
# 1        50000
# 2       350000
# 3       850000
# 4       800000
#         ...
# 125     750000
# 126     225000
# 127    1800000
# 128     450000
# 129     110000
# Name: SOLD PRICE, Length: 130, dtype: int64

# %%
g[g>g.mean()]
# Out:
# 3       850000
# 4       800000
# 7       700000
# 8       950000
# 15     1500000
# 23     1550000
# 24      725000
# 26      800000
# 27      575000
# 28      700000
# 30      850000
# 33      650000
# 37      625000
# 39      950000
# 41      975000
# 43      675000
# 44      900000
# 47      525000
# 50     1800000
# 51      800000
# 55      900000
# 59      950000
# 60      700000
# 66      650000
# 67      675000
# 69      600000
# 70      650000
# 71      800000
# 72      850000
# 77      675000
# 81      925000
# 83     1550000
# 84      550000
# 88      650000
# 91      700000
# 93     1800000
# 94      675000
# 95      950000
# 97      750000
# 101     875000
# 105     625000
# 108    1350000
# 110    1000000
# 111    1800000
# 112     675000
# 113    1600000
# 116     800000
# 119     700000
# 120     625000
# 123     750000
# 125     750000
# 127    1800000
# Name: SOLD PRICE, dtype: int64

# %%
g>g.mean()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 125     True
# 126    False
# 127     True
# 128    False
# 129    False
# Name: SOLD PRICE, Length: 130, dtype: bool

# %%
d.index
# Out:
# RangeIndex(start=0, stop=130, step=1)

# %%
d.values
# Out:
# array([[1, 'Abdulla, YA', 2, ..., 2009, 50000, 50000],
#        [2, 'Abdur Razzak', 2, ..., 2008, 50000, 50000],
#        [3, 'Agarkar, AB', 2, ..., 2008, 200000, 350000],
#        ...,
#        [128, 'Yuvraj Singh', 2, ..., 2011, 400000, 1800000],
#        [129, 'Zaheer Khan', 2, ..., 2008, 200000, 450000],
#        [130, 'Zoysa, DNT', 2, ..., 2008, 100000, 110000]], dtype=object)

# %%
d[d['SOLD PRICE']>d['SOLD PRICE'].mean()]
# Out:
#      Sl.NO.       PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  \
# 3         4         Ashwin, R    1     IND    CSK       Bowler     284
# 4         5      Badrinath, S    2     IND    CSK      Batsman      63
# 7         8     Bollinger, DE    2     AUS    CSK       Bowler      54
# 8         9          Botha, J    2      SA     RR   Allrounder      83
# 15       16         Dhoni, MS    2     IND    CSK    W. Keeper    3509
# 23       24       Flintoff, A    2     ENG    CSK   Allrounder    3845
# 24       25        Gambhir, G    2     IND    DD+      Batsman    3712
# 26       27         Gayle, CH    2      WI   KKR+   Allrounder    6373
# 27       28         Gibbs, HH    3      SA     DC      Batsman    6167
# 28       29     Gilchrist, AC    3     AUS    DC+    W. Keeper    5570
# 30       31   Harbhajan Singh    2     IND     MI       Bowler    2164
# 33       34      Henderson, T    3      SA     RR   Allrounder       0
# 37       38        Hussey, DJ    2     AUS   KKR+   Allrounder       0
# 39       40        Jadeja, RA    1     IND    RR+   Allrounder       0
# 41       42    Jayasuriya, ST    3      SL     MI   Allrounder    6973
# 43       44           Kaif, M    2     IND    RR+      Batsman     624
# 44       45        Kallis, JH    3      SA    RCB   Allrounder   12379
# 47       48       Karthik, KD    2     IND    DD+    W. Keeper    1000
# 50       51          Kohli, V    1     IND    RCB      Batsman     491
# 51       52          Kumar, P    1     IND   RCB+       Bowler     149
# 55       56            Lee, B    2     AUS   KXI+       Bowler    1451
# 59       60       Mathews, AD    1      SL   KKR+   Allrounder    1219
# 60       61      McCullum, BB    2      NZ   KKR+    W. Keeper    3763
# 66       67     Mohammad Asif    2     PAK     DD       Bowler     141
# 67       68        Morkel, JA    2      SA    CSK   Allrounder      58
# 69       70   Muralitharan, M    3      SL   CSK+       Bowler    1261
# 70       71        Nannes, DP    3     AUS    DD+       Bowler       0
# 71       72         Nayar, AM    2     IND    MI+   Allrounder       0
# 72       73          Nehra, A    2     IND    DD+       Bowler      77
# 77       78         Oram, JDP    2      NZ   CSK+   Allrounder    1780
# 81       82        Pathan, IK    2     IND  KXIP+   Allrounder    1105
# 83       84     Pietersen, KP    2     ENG   RCB+      Batsman    6654
# 84       85       Pollock, SM    3      SA     MI   Allrounder    3781
# 88       89         Raina, SK    1     IND    CSK      Batsman     710
# 91       92    Sangakkara, KC    2      SL  KXIP+    W. Keeper    9382
# 93       94         Sehwag, V    2     IND     DD      Batsman    8178
# 94       95     Shahid Afridi    2     PAK     DC   Allrounder    1716
# 95       96         Sharma, I    1     IND   KKR+       Bowler     432
# 97       98        Sharma, RG    1     IND    DC+      Batsman       0
# 101     102         Singh, RP    2     IND    DC+       Bowler     116
# 105     106      Sreesanth, S    2     IND  KXIP+       Bowler     281
# 108     109        Symonds, A    3     AUS    DC+   Allrounder    1462
# 110     111      Taylor, LRPL    2      NZ   RCB+      Batsman    2742
# 111     112     Tendulkar, SR    3     IND     MI      Batsman   15470
# 112     113        Tiwary, MK    2     IND    DD+      Batsman       0
# 113     114        Tiwary, SS    1     IND    MI+      Batsman       0
# 116     117       Uthappa, RV    2     IND   RCB+      Batsman       0
# 119     120  Venugopal Rao, Y    2     IND    DC+      Batsman       0
# 120     121       Vettori, DL    2      NZ    DD+   Allrounder    4486
# 123     124        Warner, DA    1     AUS     DD      Batsman     483
# 125     126         Yadav, AS    2     IND     DC      Batsman       0
# 127     128      Yuvraj Singh    2     IND  KXIP+      Batsman    1775
#
#      T-WKTS  ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  \
# 3        31         241     84.56  ...   76.32       0    1125    49   22.96
# 4         0          79     45.93  ...  120.71      28       0     0    0.00
# 7        50          50     92.59  ...  165.88       1     693    37   18.73
# 8        17         609     85.77  ...  114.73       3     610    19   32.11
# 15        0        6773     88.19  ...  136.45      64       0     0    0.00
# 23      226        3394     88.82  ...  116.98       2     105     2   52.50
# 24        0        4819     86.17  ...  128.90      32       0     0    0.00
# 26       72        8087     83.95  ...  161.79     129     606    13   46.62
# 27        0        8094     83.26  ...  109.79      31       0     0    0.00
# 28        0        9619     96.94  ...  140.21      86       0     0    0.00
# 30      406        1190     80.51  ...  151.41      22    1469    54   27.20
# 33        0           0      0.00  ...   68.75       1      40     1   40.00
# 37        0        1488     91.40  ...  125.78      48     345     6   57.50
# 39        0         860     78.61  ...  120.86      35     750    26   28.85
# 41       98       13430     91.21  ...  144.36      39     390    13   30.00
# 43        0        2753     72.03  ...  103.60       6       0     0    0.00
# 44      276       11498     72.97  ...  110.95      37    1713    45   38.07
# 47        0        1008     74.50  ...  123.84      28       0     0    0.00
# 50        0        3590     86.31  ...  119.29      49     345     4   86.25
# 51       27         292     88.21  ...  114.08      14    1919    53   36.21
# 55      310        1100     82.45  ...  121.18       6    1009    21   48.05
# 59        7        1447     82.59  ...  123.28      12     537    15   35.80
# 60        0        4511     89.62  ...  123.42      48       0     0    0.00
# 66      106          34     34.00  ...   50.00       0     296     8   37.00
# 67        1         782    100.25  ...  146.25      45    1899    69   27.52
# 69      800         674     77.56  ...   66.67       0    1395    57   24.47
# 70        0           1     50.00  ...   30.77       0     627    24   26.13
# 71        0           0      0.00  ...  123.19      19     263     7   37.57
# 72       44         141     57.31  ...   82.61       1    1192    48   24.83
# 77       60        2377     87.16  ...   98.15       5     327     9   36.33
# 81      100        1468     78.96  ...  128.31      34    1975    66   29.92
# 83        5        4184     86.76  ...  141.20      30     215     7   30.71
# 84      421        3519     86.69  ...  132.43       8     301    11   27.36
# 88       13        3525     92.71  ...  139.39      97     678    20   33.90
# 91        0       10472     75.75  ...  124.76      27       0     0    0.00
# 93       40        8090    104.68  ...  167.32      79     226     6   37.67
# 94       48        7040    113.87  ...  176.08       6     225     9   25.00
# 95      133          47     34.05  ...   80.43       1    1176    36   32.67
# 97        0        1961     78.85  ...  129.17      82     408    14   29.14
# 101      40         104     42.97  ...   68.42       1    1892    74   25.57
# 105      87          44     36.36  ...   64.71       0    1031    35   29.46
# 108      24        5088     92.44  ...  129.87      41     674    20   33.70
# 110       2        3185     81.77  ...  130.28      45      24     0    0.00
# 111      45       18426     86.23  ...  119.22      24      58     0    0.00
# 112       0         165     75.68  ...  113.33      22      45     1   45.00
# 113       0          49     87.50  ...  119.60      32       0     0    0.00
# 116       0         786     91.92  ...  126.17      59       0     0    0.00
# 119       0         218     60.05  ...  118.24      37     321     6   53.50
# 120     359        2105     81.93  ...  107.08       2     878    28   31.36
# 123       2         876     85.79  ...  135.76      44       0     0    0.00
# 125       0           0      0.00  ...  125.64       2       0     0    0.00
# 127       9        8051     87.58  ...  131.88      67     569    23   24.74
#
#       ECON  SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 3     6.23  22.14          2011      100000      850000
# 4     0.00   0.00          2011      100000      800000
# 7     7.22  15.57          2011      200000      700000
# 8     6.85  28.11          2011      200000      950000
# 15    0.00   0.00          2008      400000     1500000
# 23    9.55  33.00          2009      950000     1550000
# 24    0.00   0.00          2008      220000      725000
# 26    8.05  34.85          2008      250000      800000
# 27    0.00   0.00          2008      250000      575000
# 28    0.00   0.00          2008      300000      700000
# 30    6.85  23.83          2008      250000      850000
# 33    6.66  36.00          2009      100000      650000
# 37    8.85  39.00          2008      100000      625000
# 39    7.33  23.65          2011      100000      950000
# 41    7.96  22.62          2008      250000      975000
# 43    0.00   0.00          2008      125000      675000
# 44    7.96  28.71          2008      225000      900000
# 47    0.00   0.00          2008      200000      525000
# 50    8.84  58.50          2011      150000     1800000
# 51    7.73  28.11          2011      200000      800000
# 55    7.56  38.24          2008      300000      900000
# 59    8.20  26.33          2011      300000      950000
# 60    0.00   0.00          2008      175000      700000
# 66    9.25  24.00          2008      225000      650000
# 67    8.25  20.01          2008      225000      675000
# 69    6.49  22.63          2008      250000      600000
# 70    7.17  21.92          2011      200000      650000
# 71    8.74  25.86          2011       50000      800000
# 72    7.57  19.73          2011      200000      850000
# 77    9.26  23.67          2008      200000      675000
# 81    7.74  23.23          2008      200000      925000
# 83    7.41  24.86          2009     1350000     1550000
# 84    6.54  25.00          2008      200000      550000
# 88    7.05  28.90          2008      125000      650000
# 91    0.00   0.00          2008      250000      700000
# 93   10.56  21.67          2011      400000     1800000
# 94    7.50  20.00          2008      225000      675000
# 95    7.63  23.61          2008      150000      950000
# 97    8.00  21.86          2008      150000      750000
# 101   7.75  19.78          2008      200000      875000
# 105   8.25  21.43          2008      200000      625000
# 108   7.70  26.35          2008      250000     1350000
# 110  12.00   0.00          2008      400000     1000000
# 111   9.67   0.00          2011      400000     1800000
# 112  11.25  24.00          2008      100000      675000
# 113   0.00   0.00          2011      100000     1600000
# 116   0.00   0.00          2008      200000      800000
# 119   9.44  34.00          2011      100000      700000
# 120   6.81  27.75          2008      250000      625000
# 123   0.00   0.00          2011      200000      750000
# 125   0.00   0.00          2010       50000      750000
# 127   7.02  21.13          2011      400000     1800000
#
# [52 rows x 26 columns]

# %%
d['COUNTRY'].sample(frac=1,random_state=62).values
# Out:
# array(['PAK', 'IND', 'AUS', 'IND', 'AUS', 'SL', 'AUS', 'IND', 'IND',
#        'AUS', 'IND', 'IND', 'IND', 'SA', 'AUS', 'AUS', 'NZ', 'SL', 'SA',
#        'NZ', 'IND', 'AUS', 'IND', 'SL', 'IND', 'IND', 'IND', 'SA', 'AUS',
#        'IND', 'WI', 'AUS', 'AUS', 'IND', 'AUS', 'SA', 'SA', 'NZ', 'IND',
#        'NZ', 'SA', 'IND', 'IND', 'IND', 'AUS', 'IND', 'IND', 'IND', 'SL',
#        'PAK', 'PAK', 'PAK', 'AUS', 'WI', 'IND', 'SL', 'IND', 'NZ', 'IND',
#        'IND', 'SA', 'IND', 'IND', 'AUS', 'IND', 'AUS', 'PAK', 'SL', 'NZ',
#        'AUS', 'SA', 'IND', 'AUS', 'WI', 'SL', 'IND', 'IND', 'SL', 'SA',
#        'NZ', 'IND', 'IND', 'ENG', 'IND', 'AUS', 'SA', 'WI', 'IND', 'AUS',
#        'IND', 'ZIM', 'SL', 'AUS', 'IND', 'PAK', 'IND', 'IND', 'SL', 'IND',
#        'IND', 'IND', 'BAN', 'SA', 'IND', 'IND', 'SA', 'SA', 'SL', 'IND',
#        'ENG', 'WI', 'SA', 'IND', 'PAK', 'AUS', 'IND', 'IND', 'AUS', 'PAK',
#        'IND', 'SL', 'IND', 'SA', 'ENG', 'WI', 'PAK', 'SA', 'IND', 'IND',
#        'IND'], dtype=object)

# %%
d.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
d.drop(['AGE'],axis='columns').columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS',
#        'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
d.to_excel('C:/Users/Administrator/Downloads/d.xlsx', sheet_name='d', index=False)
